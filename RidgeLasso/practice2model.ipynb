# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('Algerian_forest_fires_cleaned_dataset.csv')

# %%
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI      Classes  Region
# 0  0.5  not fire          0
# 1  0.4  not fire          0
# 2  0.1  not fire          0
# 3  0.0  not fire          0
# 4  0.5  not fire          0

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
df.drop(['month','day'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4
# 2  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0
# 4  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5
#
#        Classes  Region
# 0  not fire          0
# 1  not fire          0
# 2  not fire          0
# 3  not fire          0
# 4  not fire          0

# %%
df['Classes'].value_counts()
# Out:
# Classes
# fire             131
# not fire         101
# fire               4
# fire               2
# not fire           2
# not fire           1
# not fire           1
# not fire           1
# Name: count, dtype: int64

# %%
##Encoding
df['Classes']=np.where(df['Classes'].str.contains('not fire'),0,1) #here we are changing 0 and 1 back to not fire and fire

# %%
df.head()
# Out:
#    year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  Classes  \
# 0  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5        0
# 1  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4        0
# 2  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1        0
# 3  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0        0
# 4  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5        0
#
#    Region
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df['Classes'].value_counts()
# Out:
# Classes
# 1    137
# 0    106
# Name: count, dtype: int64

# %%
##independent and dependent features
X=df.drop('FWI',axis=1) #independent features
y=df['FWI'] #dependent features

# %%
X.head()
# Out:
#    year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  Classes  Region
# 0  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4        0       0
# 1  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9        0       0
# 2  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7        0       0
# 3  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7        0       0
# 4  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9        0       0

# %%
y
# Out:
# 0      0.5
# 1      0.4
# 2      0.1
# 3      0.0
# 4      0.5
#       ...
# 238    6.5
# 239    0.0
# 240    0.2
# 241    0.7
# 242    0.5
# Name: FWI, Length: 243, dtype: float64

# %%
##train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
X_train.shape,X_test.shape
# Out:
# ((182, 12), (61, 12))

# %%
##featire selection basd on correlation
X_train.corr()
# Out:
#              year  Temperature        RH        Ws      Rain      FFMC  \
# year          NaN          NaN       NaN       NaN       NaN       NaN
# Temperature   NaN     1.000000 -0.656095 -0.305977 -0.317512  0.694768
# RH            NaN    -0.656095  1.000000  0.225736  0.241656 -0.653023
# Ws            NaN    -0.305977  0.225736  1.000000  0.251932 -0.190076
# Rain          NaN    -0.317512  0.241656  0.251932  1.000000 -0.545491
# FFMC          NaN     0.694768 -0.653023 -0.190076 -0.545491  1.000000
# DMC           NaN     0.498173 -0.414601  0.000379 -0.289754  0.620807
# DC            NaN     0.390684 -0.236078  0.096576 -0.302341  0.524101
# ISI           NaN     0.629848 -0.717804 -0.023558 -0.345707  0.750799
# BUI           NaN     0.473609 -0.362317  0.035633 -0.300964  0.607210
# Classes       NaN     0.542141 -0.456876 -0.082570 -0.369357  0.781259
# Region        NaN     0.254549 -0.394665 -0.199969 -0.059022  0.249514
#
# ...

# %%
##check for multi collinearity 
plt.figure(figsize=(12,10))
cor = X_train.corr() #dataframe correlation
sns.heatmap(cor, annot=True)
# Out:
# <Axes: >

# %%
def correlation(dataset, threshold): #basically we are removing features with correlation greater than threshold value
    col_corr = set()  # Set of all the names of deleted columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold: # we are interested in absolute coeff value
                colname = corr_matrix.columns[i]  # getting the name of column
                col_corr.add(colname)
                
    return dataset

# %%
##threshold -- Domain expertise
corr_features=correlation(X_train, 0.85)

# %%
##drop the features when correlation is greater than 0.90
X_train.drop(corr_features,axis=1,inplace=True)
X_test.drop(corr_features,axis=1,inplace=True)
X_train.shape,X_test.shape
# Out:
# ((182, 0), (61, 12))

# %%
##feature scaling of standardization

from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train_scaled=scaler.fit_transform(X_train)
X_test_scaled=scaler.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 5
#       3 from sklearn.preprocessing import StandardScaler
#       4 scaler=StandardScaler()
# ----> 5 X_train_scaled=scaler.fit_transform(X_train)
#       6 X_test_scaled=scaler.transform(X_test)
#
# File c:\Users\suraj\Documents\Python_Learn\.venv\Lib\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# ...
